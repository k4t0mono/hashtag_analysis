# %%
import pandas as pd

# %%
results_all = pd.read_csv('results_all.csv')

# %%
results_all
# Out:
#        config  test_mse  test_mae   test_r2     train_mse     train_mae  \
# 0      nnr_82  0.512706  0.644748 -0.833381  3.816862e-01  3.357941e-01
# 1      nnr_41  0.393651  0.512860 -0.407653  2.201559e-01  2.125952e-01
# 2      nnr_20  0.823072  0.639983 -1.943215  4.175956e-01  3.215311e-01
# 3  tr_default  0.085970  0.229054  0.692582  0.000000e+00  0.000000e+00
# 4     tr_d3f1  0.038631  0.186741  0.861859  5.513524e-02  1.775418e-01
# 5     tr_d3f3  0.259697  0.442696  0.071351  5.809803e-02  1.787914e-01
# 6     svr_rbf  0.076976  0.261775  0.724742  8.088732e-03  8.565094e-02
# 7    svr_poly  0.145589  0.359797  0.479389  2.908362e-02  1.321964e-01
# 8  svr_linear  0.023458  0.146868  0.916117  7.459177e-03  7.909960e-02
# 9  linear_reg  0.000538  0.018048  0.998075  9.412545e-31  7.468773e-16
#
#    train_r2
# 0 -0.866066
# 1 -0.076343
# 2 -1.041627
# 3  1.000000
# 4  0.730444
# 5  0.715958
# 6  0.960454
# 7  0.857810
# 8  0.963532
# 9  1.000000

# %%
data = pd.read_csv('data_log.csv')

# %%
data.describe()
# Out:
#        total_tweets  total_users  user_ratio_0  tweet_ratio_0  \
# count     27.000000    27.000000     27.000000      27.000000
# mean       3.791677     3.491383      0.603068       0.584138
# std        0.478848     0.455158      0.097923       0.106836
# min        3.037028     2.697229      0.462426       0.437485
# 25%        3.335976     3.057977      0.522253       0.497273
# 50%        3.930287     3.661907      0.600079       0.596525
# 75%        4.227477     3.887532      0.673333       0.649129
# max        4.469410     4.064608      0.774401       0.781215
#
#        tweet_per_user_mean_0  tweet_per_user_std_0  tweet_fav_mean_0  \
# count              27.000000             27.000000         27.000000
# mean                0.149394              0.264380          0.281391
# std                 0.066851              0.070441          0.195334
# min                 0.032358              0.114285          0.086871
# ...
